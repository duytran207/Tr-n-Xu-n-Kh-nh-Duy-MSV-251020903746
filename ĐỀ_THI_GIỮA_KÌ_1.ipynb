# %% [markdown]
# <a href="https://colab.research.google.com/github/duytran207/Tr-n-Xu-n-Kh-nh-Duy-MSV-251020903746/blob/main/%C4%90%E1%BB%80_THI_GI%E1%BB%AEA_K%C3%8C_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("n = "))
tong = 0

for i in range(1, n + 1):
  if i % 2 == 0:
    tong += i
print("tổng số chẵn từ 1 tới",n ,"có tổng là :", tong)
# Out:
# n = 10
# tổng số chẵn từ 1 tới 10 có tổng là : 30

# %%
s = input("Nhập vào một chuỗi: ")

words = s.split()

word_count = len(words)
longest_word = max(words, key=len)

print(f"số thự tự: {word_count}")
print(f"từ dài nhất: {longest_word}")
# Out:
# Nhập vào một chuỗi: hello mn nha
# số thự tự: 3
# từ dài nhất: hello

# %%
nums = list(map(int, input("Nhập các số nguyên (cách nhau bởi dấu cách): ").split()))

nums_unique = list(set(nums))

if len(nums_unique) < 2:
    print("Không tồn tại số lớn thứ hai")
else:
    nums_unique.sort()
    second_largest = nums_unique[-2]

    print("Danh sách sau khi loại trùng và sắp xếp:", nums_unique)
    print("Số lớn thứ hai là:", second_largest)
# Out:
# Nhập các số nguyên (cách nhau bởi dấu cách): 1 2 3 4 5 6 7 8 0 2 2 2 1 4 6 3
# Danh sách sau khi loại trùng và sắp xếp: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# Số lớn thứ hai là: 7

# %%
ds = list(map(float, input("Ds điểm sinh viên").split()))

ds = [d for d in ds if 0 <= d <= 10]

if ds:
    print("Điểm trung bình:", sum(ds)/len(ds))
    print("Số sinh viên đạt:", sum(d >= 5 for d in ds))
else:
    print("Không có điểm hợp lệ")
# Out:
# Ds điểm sinh viên1 2 3 4 5 5 6 77 8 9 0 00
# Điểm trung bình: 3.909090909090909
# Số sinh viên đạt: 5
